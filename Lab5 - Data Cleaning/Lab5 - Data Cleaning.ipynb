# %% [markdown]
# ## **Data Cleaning**
#
# Data cleaning involves removing unwanted characters, imputing, or dropping missing values.
#
#
# The decision is based on the dataset you have, and the information you can extract from the other columns.
#
#
# Examples of data cleaning include cleaning:
#
# 1.   **Missing Data**
# 2.   **Irregular Data** (Outliers)
# 3.   **Unnecessary Data** — Repetitive Data, Duplicates and more
# 4.   **Inconsistent Data** — Capitalization, Addresses and more

# %%
import pandas as pd
import numpy as np
def get_path(dataset_name,env_name='colab'):
    """
    This function is used to return the path of the dataset you want to use. 
    
    @params:
    dataset_name: the name of the dataset. 
    env_name: it has two values either local, or colab the default is colab
    """
    prefix = 'https://raw.githubusercontent.com/mohamed-ashry7/Data-Engineering-Lab/main/Datasets/'
    if env_name == 'colab':
        return prefix+dataset_name
    else:
        return f'../Datasets/{dataset_name}'

# %% [markdown]
# ### The null values:
#     The default null value is Nan which is not a number. But maybe in some dataset there are other symbols for null values so we shall convert it to null before handling the missing data.
#     with attribute: na_values in Pandas dataframe.
#
#
# ### Introduction to the functions.
#     1. isnull()
#     2. notnull()
#     3. dropna()
#     'how' parameter['all', 'any']
#     4. fillna()
#     the values for fillna maybe
#     - a single value for the dataframe
#     - a value for each column -> dict

# %%
missing_data25 = pd.read_csv(get_path('dataset_missing25.csv'))

# %%
missing_data25.head()
# Out:
#     COMP_K               COMP_R        COMP_RHKMFWY COMP_RHKM  \
# 0    0.261  0.18699000000000002             0.48098   0.32834
# 1  0.28343                    ?  0.6098100000000001   0.41685
# 2        ?              0.37718                   ?   0.37368
# 3  0.32233               0.1158             0.55566   0.32426
# 4  0.64987  0.29486999999999997                   ?   0.68918
#
#   MAXSW20_COMP_RHKMFWY MAXSW20_COMP_RHKM AVG_DNA_IDX          AVG_RNA_IDX  \
# 0              0.57143           0.33333           ?              0.39539
# 1              0.64286                 ?     0.53786              0.45397
# 2                  0.5               0.4           ?  0.40889000000000003
# 3              0.64286                 ?           ?              0.40052
# 4                    ?           0.66667     0.55461              0.53966
#
#           AVG_DRNA_IDX  MAXSW15_AVG_RNA_IDX Class
# 0              0.44195              0.32436    No
# 1                    ?  0.43526000000000004    No
# 2  0.43428999999999995              0.47115    No
# 3               0.5005              0.29872    No
# 4   0.5492600000000001              0.54295   Yes

# %%
missing_data25 = pd.read_csv(get_path('dataset_missing25.csv'),na_values=['?'])

# %%
missing_data25.head()
# Out:
#     COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 0  0.26100  0.18699       0.48098    0.32834               0.57143
# 1  0.28343      NaN       0.60981    0.41685               0.64286
# 2      NaN  0.37718           NaN    0.37368               0.50000
# 3  0.32233  0.11580       0.55566    0.32426               0.64286
# 4  0.64987  0.29487           NaN    0.68918                   NaN
#
#    MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 0            0.33333          NaN      0.39539       0.44195
# 1                NaN      0.53786      0.45397           NaN
# 2            0.40000          NaN      0.40889       0.43429
# 3                NaN          NaN      0.40052       0.50050
# 4            0.66667      0.55461      0.53966       0.54926
#
#    MAXSW15_AVG_RNA_IDX Class
# 0              0.32436    No
# 1              0.43526    No
# 2              0.47115    No
# 3              0.29872    No
# 4              0.54295   Yes

# %%
missing_data25.fillna(method='bfill')
# Out:
#        COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 0     0.26100  0.18699       0.48098    0.32834               0.57143
# 1     0.28343  0.37718       0.60981    0.41685               0.64286
# 2     0.32233  0.37718       0.55566    0.37368               0.50000
# 3     0.32233  0.11580       0.55566    0.32426               0.64286
# 4     0.64987  0.29487       0.47241    0.68918               0.57143
# ...       ...      ...           ...        ...                   ...
# 8790  0.27919  0.20696       0.46281    0.25139               0.71429
# 8791  0.27919  0.22313       0.47272    0.36267               0.57143
# 8792  0.22331  0.23306       0.47272    0.35527               0.57143
# 8793      NaN  0.16953       0.56138    0.44202               0.57143
# 8794      NaN  0.16953           NaN    0.22364               0.28571
#
#       MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 0               0.33333      0.53786      0.39539       0.44195
# 1               0.40000      0.53786      0.45397       0.43429
# 2               0.40000      0.55461      0.40889       0.43429
# 3               0.66667      0.55461      0.40052       0.50050
# 4               0.66667      0.55461      0.53966       0.54926
# ...                 ...          ...          ...           ...
# 8790            0.53333      0.46939      0.36191       0.46987
# 8791            0.53333      0.46939      0.36191       0.43492
# 8792            0.26667      0.46939      0.40676       0.43492
# 8793            0.26667      0.50972      0.40676       0.46410
# 8794            0.26667      0.41593      0.32869       0.37723
#
#       MAXSW15_AVG_RNA_IDX Class
# 0                 0.32436    No
# 1                 0.43526    No
# 2                 0.47115    No
# 3                 0.29872    No
# 4                 0.54295   Yes
# ...                   ...   ...
# 8790              0.47692    No
# 8791              0.41923    No
# 8792              0.76410    No
# 8793              0.29295    No
# 8794              0.29295    No
#
# [8795 rows x 11 columns]

# %%
# We can inspect these dataset to see the number of null/ notnull/ how to fill the null and so on. 
null_values = missing_data25.isnull().sum()
null_values
# Out:
# COMP_K                  2192
# COMP_R                  2204
# COMP_RHKMFWY            2242
# COMP_RHKM               2197
# MAXSW20_COMP_RHKMFWY    2105
# MAXSW20_COMP_RHKM       2240
# AVG_DNA_IDX             2245
# AVG_RNA_IDX             2222
# AVG_DRNA_IDX            2195
# MAXSW15_AVG_RNA_IDX     2218
# Class                      0
# dtype: int64

# %%
missing_data25.shape
# Out:
# (8795, 11)

# %%
# to see their percentage from the entire data. 
data_count = np.product(missing_data25.shape)
(null_values.sum()/data_count)*100
# Out:
# 22.802212000620187

# %% [markdown]
# So, about 23 percent from the data is null values.

# %%
# We can drop the null values, which will drop any row with a null value
dropped_null_values = missing_data25.dropna()
dropped_null_values
# Out:
#        COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 12    0.23755  0.21810       0.69586    0.39188               0.64286
# 20    0.24948  0.02807       0.41921    0.23296               0.57143
# 79    0.04889  0.18149       0.27386    0.14700               0.35714
# 102   0.14515  0.19646       0.39105    0.29743               0.64286
# 114   0.12173  0.33744       0.48739    0.32825               0.50000
# ...       ...      ...           ...        ...                   ...
# 8701  0.12026  0.23811       0.35919    0.26043               0.35714
# 8737  0.32338  0.12005       0.57217    0.30253               0.57143
# 8743  0.30721  0.27648       0.59651    0.44290               0.71429
# 8750  0.27639  0.13552       0.51989    0.28258               0.71429
# 8780  0.53762  0.61777       0.75065    0.73190               0.57143
#
#       MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 12              0.40000      0.55956      0.45537       0.51352
# 20              0.26667      0.33931      0.22969       0.29020
# 79              0.26667      0.35546      0.25756       0.31174
# 102             0.40000      0.43993      0.34318       0.39696
# 114             0.46667      0.54192      0.40758       0.48207
# ...                 ...          ...          ...           ...
# 8701            0.33333      0.37535      0.35581       0.36743
# 8737            0.33333      0.56700      0.39605       0.49051
# 8743            0.53333      0.49291      0.42287       0.46226
# 8750            0.46667      0.51513      0.37867       0.45425
# 8780            0.60000      0.68548      0.67697       0.68342
#
#       MAXSW15_AVG_RNA_IDX Class
# 12                0.35000    No
# 20                0.17564    No
# 79                0.26603    No
# 102               0.45962    No
# 114               0.48782    No
# ...                   ...   ...
# 8701              0.25321    No
# 8737              0.27821    No
# 8743              0.46154    No
# 8750              0.43590    No
# 8780              0.42372   Yes
#
# [463 rows x 11 columns]

# %%
# We can drop the null values, which will drop all row with a null value but still there are null values
dropped_null_values = missing_data25.dropna(axis=0)
dropped_null_values
# Out:
#        COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 12    0.23755  0.21810       0.69586    0.39188               0.64286
# 20    0.24948  0.02807       0.41921    0.23296               0.57143
# 79    0.04889  0.18149       0.27386    0.14700               0.35714
# 102   0.14515  0.19646       0.39105    0.29743               0.64286
# 114   0.12173  0.33744       0.48739    0.32825               0.50000
# ...       ...      ...           ...        ...                   ...
# 8701  0.12026  0.23811       0.35919    0.26043               0.35714
# 8737  0.32338  0.12005       0.57217    0.30253               0.57143
# 8743  0.30721  0.27648       0.59651    0.44290               0.71429
# 8750  0.27639  0.13552       0.51989    0.28258               0.71429
# 8780  0.53762  0.61777       0.75065    0.73190               0.57143
#
#       MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 12              0.40000      0.55956      0.45537       0.51352
# 20              0.26667      0.33931      0.22969       0.29020
# 79              0.26667      0.35546      0.25756       0.31174
# 102             0.40000      0.43993      0.34318       0.39696
# 114             0.46667      0.54192      0.40758       0.48207
# ...                 ...          ...          ...           ...
# 8701            0.33333      0.37535      0.35581       0.36743
# 8737            0.33333      0.56700      0.39605       0.49051
# 8743            0.53333      0.49291      0.42287       0.46226
# 8750            0.46667      0.51513      0.37867       0.45425
# 8780            0.60000      0.68548      0.67697       0.68342
#
#       MAXSW15_AVG_RNA_IDX Class
# 12                0.35000    No
# 20                0.17564    No
# 79                0.26603    No
# 102               0.45962    No
# 114               0.48782    No
# ...                   ...   ...
# 8701              0.25321    No
# 8737              0.27821    No
# 8743              0.46154    No
# 8750              0.43590    No
# 8780              0.42372   Yes
#
# [463 rows x 11 columns]

# %% [markdown]
# So dropping the null values is not a good option if there is many of them. So, We have to fill these null data. there are many algorithms and functions we can use for example: Mean Imputation, Conditional Mean Imputation, Hot Deck Imputation and many other.

# %%
# We can fill null values with just one value for the whole dataframe
missing_data25.fillna(0)
# Out:
#        COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 0     0.26100  0.18699       0.48098    0.32834               0.57143
# 1     0.28343  0.00000       0.60981    0.41685               0.64286
# 2     0.00000  0.37718       0.00000    0.37368               0.50000
# 3     0.32233  0.11580       0.55566    0.32426               0.64286
# 4     0.64987  0.29487       0.00000    0.68918               0.00000
# ...       ...      ...           ...        ...                   ...
# 8790  0.00000  0.20696       0.46281    0.25139               0.71429
# 8791  0.27919  0.22313       0.00000    0.36267               0.00000
# 8792  0.22331  0.23306       0.47272    0.35527               0.00000
# 8793  0.00000  0.00000       0.56138    0.44202               0.57143
# 8794  0.00000  0.16953       0.00000    0.22364               0.28571
#
#       MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 0               0.33333      0.00000      0.39539       0.44195
# 1               0.00000      0.53786      0.45397       0.00000
# 2               0.40000      0.00000      0.40889       0.43429
# 3               0.00000      0.00000      0.40052       0.50050
# 4               0.66667      0.55461      0.53966       0.54926
# ...                 ...          ...          ...           ...
# 8790            0.00000      0.00000      0.00000       0.46987
# 8791            0.53333      0.00000      0.36191       0.00000
# 8792            0.00000      0.46939      0.00000       0.43492
# 8793            0.00000      0.50972      0.40676       0.46410
# 8794            0.26667      0.41593      0.32869       0.37723
#
#       MAXSW15_AVG_RNA_IDX Class
# 0                 0.32436    No
# 1                 0.43526    No
# 2                 0.47115    No
# 3                 0.29872    No
# 4                 0.54295   Yes
# ...                   ...   ...
# 8790              0.47692    No
# 8791              0.41923    No
# 8792              0.76410    No
# 8793              0.00000    No
# 8794              0.29295    No
#
# [8795 rows x 11 columns]

# %%
# or with a dict
missing_data25.fillna({'COMP_K':0.1,'COMP_R':0.2})
# Out:
#        COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 0     0.26100  0.18699       0.48098    0.32834               0.57143
# 1     0.28343  0.20000       0.60981    0.41685               0.64286
# 2     0.10000  0.37718           NaN    0.37368               0.50000
# 3     0.32233  0.11580       0.55566    0.32426               0.64286
# 4     0.64987  0.29487           NaN    0.68918                   NaN
# ...       ...      ...           ...        ...                   ...
# 8790  0.10000  0.20696       0.46281    0.25139               0.71429
# 8791  0.27919  0.22313           NaN    0.36267                   NaN
# 8792  0.22331  0.23306       0.47272    0.35527                   NaN
# 8793  0.10000  0.20000       0.56138    0.44202               0.57143
# 8794  0.10000  0.16953           NaN    0.22364               0.28571
#
#       MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 0               0.33333          NaN      0.39539       0.44195
# 1                   NaN      0.53786      0.45397           NaN
# 2               0.40000          NaN      0.40889       0.43429
# 3                   NaN          NaN      0.40052       0.50050
# 4               0.66667      0.55461      0.53966       0.54926
# ...                 ...          ...          ...           ...
# 8790                NaN          NaN          NaN       0.46987
# 8791            0.53333          NaN      0.36191           NaN
# 8792                NaN      0.46939          NaN       0.43492
# 8793                NaN      0.50972      0.40676       0.46410
# 8794            0.26667      0.41593      0.32869       0.37723
#
#       MAXSW15_AVG_RNA_IDX Class
# 0                 0.32436    No
# 1                 0.43526    No
# 2                 0.47115    No
# 3                 0.29872    No
# 4                 0.54295   Yes
# ...                   ...   ...
# 8790              0.47692    No
# 8791              0.41923    No
# 8792              0.76410    No
# 8793                  NaN    No
# 8794              0.29295    No
#
# [8795 rows x 11 columns]

# %%
# Or even a forward fill/ backward fill
missing_data25.fillna(method='ffill') # backward fill -> bfill
# Out:
#        COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 0     0.26100  0.18699       0.48098    0.32834               0.57143
# 1     0.28343  0.18699       0.60981    0.41685               0.64286
# 2     0.28343  0.37718       0.60981    0.37368               0.50000
# 3     0.32233  0.11580       0.55566    0.32426               0.64286
# 4     0.64987  0.29487       0.55566    0.68918               0.64286
# ...       ...      ...           ...        ...                   ...
# 8790  0.15399  0.20696       0.46281    0.25139               0.71429
# 8791  0.27919  0.22313       0.46281    0.36267               0.71429
# 8792  0.22331  0.23306       0.47272    0.35527               0.71429
# 8793  0.22331  0.23306       0.56138    0.44202               0.57143
# 8794  0.22331  0.16953       0.56138    0.22364               0.28571
#
#       MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 0               0.33333          NaN      0.39539       0.44195
# 1               0.33333      0.53786      0.45397       0.44195
# 2               0.40000      0.53786      0.40889       0.43429
# 3               0.40000      0.53786      0.40052       0.50050
# 4               0.66667      0.55461      0.53966       0.54926
# ...                 ...          ...          ...           ...
# 8790            0.40000      0.49538      0.47035       0.46987
# 8791            0.53333      0.49538      0.36191       0.46987
# 8792            0.53333      0.46939      0.36191       0.43492
# 8793            0.53333      0.50972      0.40676       0.46410
# 8794            0.26667      0.41593      0.32869       0.37723
#
#       MAXSW15_AVG_RNA_IDX Class
# 0                 0.32436    No
# 1                 0.43526    No
# 2                 0.47115    No
# 3                 0.29872    No
# 4                 0.54295   Yes
# ...                   ...   ...
# 8790              0.47692    No
# 8791              0.41923    No
# 8792              0.76410    No
# 8793              0.76410    No
# 8794              0.29295    No
#
# [8795 rows x 11 columns]

# %%
# Mean imputation of the first column
mean_first_column = missing_data25.iloc[:,0].notnull().mean()
print(mean_first_column)
missing_data25.iloc[:,0] = missing_data25.iloc[:,0].fillna(mean_first_column)
missing_data25.head()
# Out:
# 0.750767481523593
#      COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 0  0.261000  0.18699       0.48098    0.32834               0.57143
# 1  0.283430      NaN       0.60981    0.41685               0.64286
# 2  0.750767  0.37718           NaN    0.37368               0.50000
# 3  0.322330  0.11580       0.55566    0.32426               0.64286
# 4  0.649870  0.29487           NaN    0.68918                   NaN
#
#    MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 0            0.33333          NaN      0.39539       0.44195
# 1                NaN      0.53786      0.45397           NaN
# 2            0.40000          NaN      0.40889       0.43429
# 3                NaN          NaN      0.40052       0.50050
# 4            0.66667      0.55461      0.53966       0.54926
#
#    MAXSW15_AVG_RNA_IDX Class
# 0              0.32436    No
# 1              0.43526    No
# 2              0.47115    No
# 3              0.29872    No
# 4              0.54295   Yes

# %%
# Mode imputation of the second column
median_second_column = missing_data25.iloc[:,1].notnull().median()
print(median_second_column)
missing_data25.iloc[:,1] = missing_data25.iloc[:,1].fillna(median_second_column)
missing_data25.head()
# Out:
# 1.0
#      COMP_K   COMP_R  COMP_RHKMFWY  COMP_RHKM  MAXSW20_COMP_RHKMFWY  \
# 0  0.261000  0.18699       0.48098    0.32834               0.57143
# 1  0.283430  1.00000       0.60981    0.41685               0.64286
# 2  0.750767  0.37718           NaN    0.37368               0.50000
# 3  0.322330  0.11580       0.55566    0.32426               0.64286
# 4  0.649870  0.29487           NaN    0.68918                   NaN
#
#    MAXSW20_COMP_RHKM  AVG_DNA_IDX  AVG_RNA_IDX  AVG_DRNA_IDX  \
# 0            0.33333          NaN      0.39539       0.44195
# 1                NaN      0.53786      0.45397           NaN
# 2            0.40000          NaN      0.40889       0.43429
# 3                NaN          NaN      0.40052       0.50050
# 4            0.66667      0.55461      0.53966       0.54926
#
#    MAXSW15_AVG_RNA_IDX Class
# 0              0.32436    No
# 1              0.43526    No
# 2              0.47115    No
# 3              0.29872    No
# 4              0.54295   Yes

# %% [markdown]
# ### **The Nobel Prize Dataset**
#
# The Nobel Prize , is a set of annual international awards bestowed in several categories by Swedish and Norwegian institutions in recognition of academic, cultural, or scientific advances.
#
# The will of the Swedish scientist Alfred Nobel established the five Nobel prizes in 1895. The prizes in Chemistry, Literature, Peace, Physics, and Physiology or Medicine were first awarded in 1901.The Nobel Prize is widely regarded as the most prestigious award available in the fields of literature, medicine, physics, chemistry, economics and activism for peace.

# %% [markdown]
# Let's start by reading the dataset then exploring if there are any missing values

# %%
nobel_prize_df = pd.read_csv(get_path('nobel.csv'))

# %% [markdown]
# Observe the first few rows

# %%
nobel_prize_df.head()
# Out:
#    Year    Category                                           Prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           Motivation Prize Share  Laureate ID  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   Laureate Type                     Full Name  Birth Date         Birth City  \
# 0    Individual  Jacobus Henricus van 't Hoff  1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme  1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring  1854-03-15  Hansdorf (Lawice)
# 3    Individual             Jean Henry Dunant  1828-05-08             Geneva
# 4    Individual                Frédéric Passy  1822-05-20              Paris
#
#       Birth Country   Sex   Organization Name Organization City  \
# 0       Netherlands  Male   Berlin University            Berlin
# 1            France  Male                 NaN               NaN
# 2  Prussia (Poland)  Male  Marburg University           Marburg
# 3       Switzerland  Male                 NaN               NaN
# 4            France  Male                 NaN               NaN
#
#   Organization Country  Death Date Death City Death Country
# 0              Germany  1911-03-01     Berlin       Germany
# 1                  NaN  1907-09-07   Châtenay        France
# 2              Germany  1917-03-31    Marburg       Germany
# 3                  NaN  1910-10-30     Heiden   Switzerland
# 4                  NaN  1912-06-12      Paris        France

# %%
print(nobel_prize_df.shape)
nobel_prize_df.info()
# Out:
# (969, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969 entries, 0 to 968
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  969 non-null    int64
#  1   Category              969 non-null    object
#  2   Prize                 969 non-null    object
#  3   Motivation            881 non-null    object
#  4   Prize Share           969 non-null    object
#  5   Laureate ID           969 non-null    int64
#  6   Laureate Type         969 non-null    object
#  7   Full Name             969 non-null    object
#  8   Birth Date            940 non-null    object
#  9   Birth City            941 non-null    object
#  10  Birth Country         943 non-null    object
#  11  Sex                   943 non-null    object
#  12  Organization Name     722 non-null    object
#  13  Organization City     716 non-null    object
#  14  Organization Country  716 non-null    object
#  15  Death Date            617 non-null    object
#  16  Death City            599 non-null    object
#  17  Death Country         605 non-null    object
# dtypes: int64(2), object(16)
# memory usage: 136.4+ KB

# %%
nobel_prize_df.notnull().sum()
# Out:
# Year                    969
# Category                969
# Prize                   969
# Motivation              881
# Prize Share             969
# Laureate ID             969
# Laureate Type           969
# Full Name               969
# Birth Date              940
# Birth City              941
# Birth Country           943
# Sex                     943
# Organization Name       722
# Organization City       716
# Organization Country    716
# Death Date              617
# Death City              599
# Death Country           605
# dtype: int64

# %% [markdown]
# From the above cell result, we can observe that there are missing values for several columns. Let's start by the Birth Date, and try to understand why is it missing.

# %%
#another way to find the null values
nobel_prize_df.isnull().sum()
# Out:
# Year                      0
# Category                  0
# Prize                     0
# Motivation               88
# Prize Share               0
# Laureate ID               0
# Laureate Type             0
# Full Name                 0
# Birth Date               29
# Birth City               28
# Birth Country            26
# Sex                      26
# Organization Name       247
# Organization City       253
# Organization Country    253
# Death Date              352
# Death City              370
# Death Country           364
# dtype: int64

# %%
nobel_prize_df[nobel_prize_df['Birth City'].isnull()]
# Out:
#      Year    Category                               Prize  \
# 24   1904       Peace          The Nobel Peace Prize 1904
# 61   1910       Peace          The Nobel Peace Prize 1910
# 90   1917       Peace          The Nobel Peace Prize 1917
# 206  1938       Peace          The Nobel Peace Prize 1938
# 222  1944       Peace          The Nobel Peace Prize 1944
# 244  1947       Peace          The Nobel Peace Prize 1947
# 245  1947       Peace          The Nobel Peace Prize 1947
# 295  1954       Peace          The Nobel Peace Prize 1954
# 365  1963       Peace          The Nobel Peace Prize 1963
# 366  1963       Peace          The Nobel Peace Prize 1963
# 383  1965       Peace          The Nobel Peace Prize 1965
# 416  1969       Peace          The Nobel Peace Prize 1969
# 498  1977       Peace          The Nobel Peace Prize 1977
# 543  1981       Peace          The Nobel Peace Prize 1981
# 578  1985       Peace          The Nobel Peace Prize 1985
# 610  1988       Peace          The Nobel Peace Prize 1988
# 682  1995       Peace          The Nobel Peace Prize 1995
# 705  1997       Peace          The Nobel Peace Prize 1997
# 728  1999       Peace          The Nobel Peace Prize 1999
# 750  2001  Literature  The Nobel Prize in Literature 2001
# 754  2001       Peace          The Nobel Peace Prize 2001
# 808  2005       Peace          The Nobel Peace Prize 2005
# 821  2006       Peace          The Nobel Peace Prize 2006
# 833  2007       Peace          The Nobel Peace Prize 2007
# 880  2010       Peace          The Nobel Peace Prize 2010
# 909  2012       Peace          The Nobel Peace Prize 2012
# 927  2013       Peace          The Nobel Peace Prize 2013
# 955  2015       Peace          The Nobel Peace Prize 2015
#
#                                             Motivation Prize Share  \
# 24                                                 NaN         1/1
# 61                                                 NaN         1/1
# 90                                                 NaN         1/1
# 206                                                NaN         1/1
# 222                                                NaN         1/1
# 244                                                NaN         1/2
# 245                                                NaN         1/2
# 295                                                NaN         1/1
# 365                                                NaN         1/2
# 366                                                NaN         1/2
# 383                                                NaN         1/1
# 416                                                NaN         1/1
# 498                                                NaN         1/1
# 543                                                NaN         1/1
# 578                                                NaN         1/1
# 610                                                NaN         1/1
# 682  "for their efforts to diminish the part played...         1/2
# 705  "for their work for the banning and clearing o...         1/2
# 728  "in recognition of the organization's pioneeri...         1/1
# 750  "for having united perceptive narrative and in...         1/1
# 754  "for their work for a better organized and mor...         1/2
# 808  "for their efforts to prevent nuclear energy f...         1/2
# 821  "for their efforts to create economic and soci...         1/2
# 833  "for their efforts to build up and disseminate...         1/2
# 880  "for his long and non-violent struggle for fun...         1/1
# 909  "for over six decades contributed to the advan...         1/1
# 927  "for its extensive efforts to eliminate chemic...         1/1
# 955  "for its decisive contribution to the building...         1/1
#
#      Laureate ID Laureate Type  \
# 24           467  Organization
# 61           477  Organization
# 90           482  Organization
# 206          503  Organization
# 222          482  Organization
# 244          508  Organization
# 245          509  Organization
# 295          515  Organization
# 365          482  Organization
# 366          523  Organization
# 383          525  Organization
# 416          527  Organization
# 498          537  Organization
# 543          515  Organization
# 578          547  Organization
# 610          550  Organization
# 682          561  Organization
# 705          564  Organization
# 728          568  Organization
# 750          747    Individual
# 754          748  Organization
# 808          797  Organization
# 821          810  Organization
# 833          818  Organization
# 880          855    Individual
# 909          881  Organization
# 927          893  Organization
# 955          925  Organization
#
#                                              Full Name  Birth Date Birth City  \
# 24   Institut de droit international (Institute of ...         NaN        NaN
# 61   Bureau international permanent de la Paix (Per...         NaN        NaN
# 90   Comité international de la Croix Rouge (Intern...         NaN        NaN
# 206  Office international Nansen pour les Réfugiés ...         NaN        NaN
# 222  Comité international de la Croix Rouge (Intern...         NaN        NaN
# 244              Friends Service Council (The Quakers)         NaN        NaN
# 245   American Friends Service Committee (The Quakers)         NaN        NaN
# 295  Office of the United Nations High Commissioner...         NaN        NaN
# 365  Comité international de la Croix Rouge (Intern...         NaN        NaN
# 366  Ligue des Sociétés de la Croix-Rouge (League o...         NaN        NaN
# 383            United Nations Children's Fund (UNICEF)         NaN        NaN
# 416         International Labour Organization (I.L.O.)         NaN        NaN
# 498                              Amnesty International         NaN        NaN
# 543  Office of the United Nations High Commissioner...         NaN        NaN
# 578  International Physicians for the Prevention of...         NaN        NaN
# 610                 United Nations Peacekeeping Forces         NaN        NaN
# 682   Pugwash Conferences on Science and World Affairs         NaN        NaN
# 705     International Campaign to Ban Landmines (ICBL)         NaN        NaN
# 728                           Médecins Sans Frontières         NaN        NaN
# 750                  Sir Vidiadhar Surajprasad Naipaul  1932-08-17        NaN
# 754                              United Nations (U.N.)         NaN        NaN
# 808          International Atomic Energy Agency (IAEA)         NaN        NaN
# 821                                       Grameen Bank         NaN        NaN
# 833   Intergovernmental Panel on Climate Change (IPCC)         NaN        NaN
# 880                                         Liu Xiaobo  1955-12-28        NaN
# 909                                European Union (EU)         NaN        NaN
# 927  Organisation for the Prohibition of Chemical W...         NaN        NaN
# 955                          National Dialogue Quartet         NaN        NaN
#
#     Birth Country   Sex Organization Name Organization City  \
# 24            NaN   NaN               NaN               NaN
# 61            NaN   NaN               NaN               NaN
# 90            NaN   NaN               NaN               NaN
# 206           NaN   NaN               NaN               NaN
# 222           NaN   NaN               NaN               NaN
# 244           NaN   NaN               NaN               NaN
# 245           NaN   NaN               NaN               NaN
# 295           NaN   NaN               NaN               NaN
# 365           NaN   NaN               NaN               NaN
# 366           NaN   NaN               NaN               NaN
# 383           NaN   NaN               NaN               NaN
# 416           NaN   NaN               NaN               NaN
# 498           NaN   NaN               NaN               NaN
# 543           NaN   NaN               NaN               NaN
# 578           NaN   NaN               NaN               NaN
# 610           NaN   NaN               NaN               NaN
# 682           NaN   NaN               NaN               NaN
# 705           NaN   NaN               NaN               NaN
# 728           NaN   NaN               NaN               NaN
# 750      Trinidad  Male               NaN               NaN
# 754           NaN   NaN               NaN               NaN
# 808           NaN   NaN               NaN               NaN
# 821           NaN   NaN               NaN               NaN
# 833           NaN   NaN               NaN               NaN
# 880         China  Male               NaN               NaN
# 909           NaN   NaN               NaN               NaN
# 927           NaN   NaN               NaN               NaN
# 955           NaN   NaN               NaN               NaN
#
#     Organization Country Death Date Death City Death Country
# 24                   NaN        NaN        NaN           NaN
# 61                   NaN        NaN        NaN           NaN
# 90                   NaN        NaN        NaN           NaN
# 206                  NaN        NaN        NaN           NaN
# 222                  NaN        NaN        NaN           NaN
# 244                  NaN        NaN        NaN           NaN
# 245                  NaN        NaN        NaN           NaN
# 295                  NaN        NaN        NaN           NaN
# 365                  NaN        NaN        NaN           NaN
# 366                  NaN        NaN        NaN           NaN
# 383                  NaN        NaN        NaN           NaN
# 416                  NaN        NaN        NaN           NaN
# 498                  NaN        NaN        NaN           NaN
# 543                  NaN        NaN        NaN           NaN
# 578                  NaN        NaN        NaN           NaN
# 610                  NaN        NaN        NaN           NaN
# 682                  NaN        NaN        NaN           NaN
# 705                  NaN        NaN        NaN           NaN
# 728                  NaN        NaN        NaN           NaN
# 750                  NaN        NaN        NaN           NaN
# 754                  NaN        NaN        NaN           NaN
# 808                  NaN        NaN        NaN           NaN
# 821                  NaN        NaN        NaN           NaN
# 833                  NaN        NaN        NaN           NaN
# 880                  NaN        NaN        NaN           NaN
# 909                  NaN        NaN        NaN           NaN
# 927                  NaN        NaN        NaN           NaN
# 955                  NaN        NaN        NaN           NaN

# %% [markdown]
# If we observe the dataframe above, we notice that the `Birth Date`,	`Birth City`,	`Birth Country`,	`Sex`,	`Organization Name`,	`Organization City`,	`Organization Country`,	`Death Date`,`	Death City`, and	`Death Country` are also missing. However, when we check the `Laureate Type` column, we observe that most of them belong to an *Organization*. Hence, those values are missing for a reason.
#
# Therefore, not every value which is missing, we shall impute. What imputation means is infering the missing values from other columns or the same column, through mean,median, and mode for example.

# %% [markdown]
# Let's try to analyze another column. That is the `Death Date` column, why doesn't it exist? Is it because the laureates still didn't die, or because the laureate is an organization, or is it because it wasn't recorded?

# %%
nobel_prize_df[((nobel_prize_df['Death Date'].isnull()) & (nobel_prize_df['Laureate Type']!='Organization'))]
# Out:
#      Year   Category                                           Prize  \
# 318  1957    Physics                 The Nobel Prize in Physics 1957
# 319  1957    Physics                 The Nobel Prize in Physics 1957
# 355  1962   Medicine  The Nobel Prize in Physiology or Medicine 1962
# 393  1967  Chemistry               The Nobel Prize in Chemistry 1967
# 417  1969    Physics                 The Nobel Prize in Physics 1969
# ..    ...        ...                                             ...
# 964  2016   Medicine  The Nobel Prize in Physiology or Medicine 2016
# 965  2016      Peace                      The Nobel Peace Prize 2016
# 966  2016    Physics                 The Nobel Prize in Physics 2016
# 967  2016    Physics                 The Nobel Prize in Physics 2016
# 968  2016    Physics                 The Nobel Prize in Physics 2016
#
#                                             Motivation Prize Share  \
# 318  "for their penetrating investigation of the so...         1/2
# 319  "for their penetrating investigation of the so...         1/2
# 355  "for their discoveries concerning the molecula...         1/3
# 393  "for their studies of extremely fast chemical ...         1/2
# 417  "for his contributions and discoveries concern...         1/1
# ..                                                 ...         ...
# 964  "for his discoveries of mechanisms for autophagy"         1/1
# 965  "for his resolute efforts to bring the country...         1/1
# 966  "for theoretical discoveries of topological ph...         1/2
# 967  "for theoretical discoveries of topological ph...         1/4
# 968  "for theoretical discoveries of topological ph...         1/4
#
#      Laureate ID Laureate Type              Full Name  Birth Date  \
# 318           68    Individual         Chen Ning Yang  1922-09-22
# 319           69    Individual   Tsung-Dao (T.D.) Lee  1926-11-24
# 355          373    Individual     James Dewey Watson  1928-04-06
# 393          233    Individual          Manfred Eigen  1927-05-09
# 417           90    Individual       Murray Gell-Mann  1929-09-15
# ..           ...           ...                    ...         ...
# 964          927    Individual       Yoshinori Ohsumi  1945-02-09
# 965          934    Individual     Juan Manuel Santos  1951-08-10
# 966          928    Individual      David J. Thouless  1934-09-21
# 967          929    Individual   F. Duncan M. Haldane  1951-09-14
# 968          930    Individual  J. Michael Kosterlitz  1943-06-22
#
#         Birth City             Birth Country   Sex  \
# 318  Hofei, Anhwei                     China  Male
# 319       Shanghai                     China  Male
# 355    Chicago, IL  United States of America  Male
# 393         Bochum                   Germany  Male
# 417   New York, NY  United States of America  Male
# ..             ...                       ...   ...
# 964        Fukuoka                     Japan  Male
# 965         Bogotá                  Colombia  Male
# 966       Bearsden            United Kingdom  Male
# 967         London            United Kingdom  Male
# 968       Aberdeen            United Kingdom  Male
#
#                                 Organization Name Organization City  \
# 318                  Institute for Advanced Study     Princeton, NJ
# 319                           Columbia University      New York, NY
# 355                            Harvard University     Cambridge, MA
# 393  Max-Planck-Institut für Physikalische Chemie         Göttingen
# 417  California Institute of Technology (Caltech)      Pasadena, CA
# ..                                            ...               ...
# 964                 Tokyo Institute of Technology             Tokyo
# 965                                           NaN               NaN
# 966                      University of Washington       Seattle, WA
# 967                          Princeton University     Princeton, NJ
# 968                              Brown University    Providence, RI
#
#             Organization Country Death Date Death City Death Country
# 318     United States of America        NaN        NaN           NaN
# 319     United States of America        NaN        NaN           NaN
# 355     United States of America        NaN        NaN           NaN
# 393  Federal Republic of Germany        NaN        NaN           NaN
# 417     United States of America        NaN        NaN           NaN
# ..                           ...        ...        ...           ...
# 964                        Japan        NaN        NaN           NaN
# 965                          NaN        NaN        NaN           NaN
# 966     United States of America        NaN        NaN           NaN
# 967     United States of America        NaN        NaN           NaN
# 968     United States of America        NaN        NaN           NaN
#
# [324 rows x 18 columns]

# %% [markdown]
# Most of the names mentioned here, are still alive or passed away after this dataset has been released, 2019. So we can assume for instance that those with missing death dates are still alive. That is when we come to calculate the age by subtracting `Birth Date` form the `Death Date` we can replace the null values in the `Death Date` by 2020 to compute the age.

# %%
# To fill NaNs with a certain value use the fillna() method, we can do that under a certain condition
nobel_prize_df['Death Date'] = nobel_prize_df[nobel_prize_df['Laureate Type']!='Organization']["Death Date"].fillna(2020)
nobel_prize_df.loc[967]
# Out:
# Year                                                                 2016
# Category                                                          Physics
# Prize                                     The Nobel Prize in Physics 2016
# Motivation              "for theoretical discoveries of topological ph...
# Prize Share                                                           1/4
# Laureate ID                                                           929
# Laureate Type                                                  Individual
# Full Name                                            F. Duncan M. Haldane
# Birth Date                                                     1951-09-14
# Birth City                                                         London
# Birth Country                                              United Kingdom
# Sex                                                                  Male
# Organization Name                                    Princeton University
# Organization City                                           Princeton, NJ
# Organization Country                             United States of America
# Death Date                                                           2020
# Death City                                                            NaN
# Death Country                                                         NaN
# Name: 967, dtype: object

# %% [markdown]
# Now let's observe how many Death Dates are still null. Probably, those who are related to an `Organization`.

# %%
nobel_prize_df.isnull().sum()
# Out:
# Year                      0
# Category                  0
# Prize                     0
# Motivation               88
# Prize Share               0
# Laureate ID               0
# Laureate Type             0
# Full Name                 0
# Birth Date               29
# Birth City               28
# Birth Country            26
# Sex                      26
# Organization Name       247
# Organization City       253
# Organization Country    253
# Death Date               30
# Death City              370
# Death Country           364
# dtype: int64

# %% [markdown]
# Notice how we went from 300+ missing values to 30 only!

# %%
nobel_prize_df[nobel_prize_df['Laureate Type']=='Organization'].isnull().sum()
# Out:
# Year                     0
# Category                 0
# Prize                    0
# Motivation              19
# Prize Share              0
# Laureate ID              0
# Laureate Type            0
# Full Name                0
# Birth Date              26
# Birth City              26
# Birth Country           26
# Sex                     26
# Organization Name       30
# Organization City       30
# Organization Country    30
# Death Date              30
# Death City              28
# Death Country           28
# dtype: int64

# %% [markdown]
# Note that the other 30 missing values are coming from Organization winners

# %% [markdown]
# ### **Cars Data Set**

# %%
import pandas as pd
df_cars= pd.read_csv(get_path('cars.csv'), sep=";")
df_cars.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu     NaN         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0        NaN
# 3         Plymouth Satellite     NaN         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8          NaN      150.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4     NaN         12.0    70     US

# %% [markdown]
# Let's observe the columns with null values. We have two ways to go. Either by using the `info() `function or by using `isnull().sum()` function

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           407 non-null    object
#  1   MPG           404 non-null    object
#  2   Cylinders     407 non-null    object
#  3   Displacement  406 non-null    object
#  4   Horsepower    405 non-null    object
#  5   Weight        406 non-null    object
#  6   Acceleration  407 non-null    object
#  7   Model         407 non-null    object
#  8   Origin        407 non-null    object
# dtypes: object(9)
# memory usage: 28.7+ KB

# %%
# get the number of missing data points per column
missing_values_count_cars = df_cars.isnull().sum()
#look at the missing value
print(missing_values_count_cars)
# Out:
# Car             0
# MPG             3
# Cylinders       0
# Displacement    1
# Horsepower      2
# Weight          1
# Acceleration    0
# Model           0
# Origin          0
# dtype: int64

# %% [markdown]
# There aren't many missing values. Let's take a glimpse at the percentage of the missing values:
#
# **HINT:** We'll need `Numpy` for the below task.

# %%
import numpy as np
# How many total missing values do we have?
# shape returns the dimentionality of a dataframe (rows and columns), can you guess what product will do?
total_cells_cars = np.product(df_cars.shape) 
total_missing_cars = missing_values_count_cars.sum()

# percent of data that is missing
percentage_missign_values_cars = (total_missing_cars/total_cells_cars) * 100
print(percentage_missign_values_cars)
# Out:
# 0.19110019110019108

# %% [markdown]
# Around *0.19%* of the values are missing, which isn't a lot. Therefore, we might go with the option of dropping all the rows with null values.

# %%
df_cars_cleaned = df_cars.dropna() #this will drop the rows with null values
df_cars_cleaned.head()
# Out:
#                  Car     MPG Cylinders Displacement Horsepower  Weight  \
# 0             STRING  DOUBLE       INT       DOUBLE     DOUBLE  DOUBLE
# 5        Ford Torino    17.0         8        302.0      140.0   3449.
# 7   Chevrolet Impala    14.0         8        454.0      220.0   4354.
# 8  Plymouth Fury iii    14.0         8        440.0      215.0   4312.
# 9   Pontiac Catalina    14.0         8        455.0      225.0   4425.
#
#   Acceleration Model Origin
# 0       DOUBLE   INT    CAT
# 5         10.5    70     US
# 7          9.0    70     US
# 8          8.5    70     US
# 9         10.0    70     US

# %%
df_cars_cleaned_null_cols = df_cars.dropna(axis=1) #this will drop the columns with null values
df_cars_cleaned_null_cols.head()
# Out:
#                          Car Cylinders Acceleration Model Origin
# 0                     STRING       INT       DOUBLE   INT    CAT
# 1  Chevrolet Chevelle Malibu         8         12.0    70     US
# 2          Buick Skylark 320         8         11.5    70     US
# 3         Plymouth Satellite         8         11.0    70     US
# 4              AMC Rebel SST         8         12.0    70     US

# %% [markdown]
# Let's observe how many columns we lost

# %%
print("Columns in original dataset: %d \n" % df_cars.shape[1])
print("Columns with na's dropped: %d" % df_cars_cleaned_null_cols.shape[1])
# Out:
# Columns in original dataset: 9
#
# Columns with na's dropped: 5

# %% [markdown]
# ### **Cars Dataset - Filling in missing values automatically**
#
# Another option is to try and fill in the missing values through imputations.

# %% [markdown]
# Let's take the `MPG` column for example. We can fill in the missing values with 0s through the following line of code:
#
# `df_cars.fillna(0) `.

# %%
df_cars_temp = df_cars.fillna(0)

# %%
df_cars_temp.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu       0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0          0
# 3         Plymouth Satellite       0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8            0      150.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4       0         12.0    70     US

# %% [markdown]
# However, this does not make much sense as there isn't MPG equal to 0. How about we plot the MPG column and if it follows a random distribution we can use the mean of the column to compute the missing values. Otherwise, we can use the median (if there is a skewed normal distribution). However, there might be a better way of imputation which is getting the median or the mean of the MPG of the cars with similar attributes.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
current_MPG = df_cars_cleaned.loc[1:,]['MPG']
current_MPG = current_MPG.astype(float)

# %%
mpg_list = current_MPG.sort_values(ascending=True).values.tolist()

# %%
bins = [0,5,10,15,20,25,30,35,40,45,50]
ax = sns.distplot(mpg_list,bins=bins,kde=True)
ax.set(xlabel="MPG",ylabel="Count")
# Out:
# [Text(0, 0.5, 'Count'), Text(0.5, 0, 'MPG')]

# %% [markdown]
# If we observe the graph above, we can consider it in a way or another normally distributed. Therefore, we can impute the missing values using the mean.

# %%
df_cars = df_cars.iloc[1:] #drop the first row from df_cars

# %%
df_cars_cleaned = df_cars_cleaned.iloc[1:] #drop the first row from df_cars_cleaned
df_cars_cleaned
# Out:
#                     Car   MPG Cylinders Displacement Horsepower Weight  \
# 5           Ford Torino  17.0         8        302.0      140.0  3449.
# 7      Chevrolet Impala  14.0         8        454.0      220.0  4354.
# 8     Plymouth Fury iii  14.0         8        440.0      215.0  4312.
# 9      Pontiac Catalina  14.0         8        455.0      225.0  4425.
# 10   AMC Ambassador DPL  15.0         8        390.0      190.0  3850.
# ..                  ...   ...       ...          ...        ...    ...
# 402     Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403   Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404       Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405         Ford Ranger  28.0         4        120.0      79.00  2625.
# 406          Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# 5           10.5    70      US
# 7            9.0    70      US
# 8            8.5    70      US
# 9           10.0    70      US
# 10           8.5    70      US
# ..           ...   ...     ...
# 402         15.6    82      US
# 403         24.6    82  Europe
# 404         11.6    82      US
# 405         18.6    82      US
# 406         19.4    82      US
#
# [401 rows x 9 columns]

# %% [markdown]
# To compute the mean we need numeric values. However the values in the dataframe are objects. Therefore, we need to change them to numerics so that we can compute them.

# %%
#convert the following column to float
df_cars_cleaned['MPG'] = df_cars_cleaned['MPG'].astype(float)

# %% [markdown]
# Now let's see what is the mean of the MPG column

# %%
np.mean (df_cars_cleaned['MPG'])
# Out:
# 23.13416458852868

# %% [markdown]
# We can use this mean to compute the missing values since the graph demonstarted a normal distribution

# %%
df_cars['MPG'].fillna((df_cars_cleaned['MPG'].mean()), inplace=True) #inplace doesnt require me to aassign result to a new df

# %%
df_cars.head()
# Out:
#                          Car      MPG Cylinders Displacement Horsepower  \
# 1  Chevrolet Chevelle Malibu  23.1342         8        307.0      130.0
# 2          Buick Skylark 320     15.0         8        350.0        NaN
# 3         Plymouth Satellite  23.1342         8        318.0      150.0
# 4              AMC Rebel SST     16.0         8          NaN      150.0
# 5                Ford Torino     17.0         8        302.0      140.0
#
#   Weight Acceleration Model Origin
# 1  3504.         12.0    70     US
# 2  3693.         11.5    70     US
# 3  3436.         11.0    70     US
# 4    NaN         12.0    70     US
# 5  3449.         10.5    70     US

# %% [markdown]
# ### **Car Dataset - Simple Imputer**

# %% [markdown]
# *SimpleImputer* is a `scikit-learn` class which is helpful in handling the missing data in the predictive model dataset. It replaces the `NaN` values with a specified placeholder.
# It is implemented by the use of the `SimpleImputer()` method which takes the following arguments :
#
# `missing_values` : The missing_values placeholder which has to be imputed. By default is NaN
#
# `strategy` : The data which will replace the NaN values from the dataset. The strategy argument can take the values – ‘mean'(default), ‘median’, ‘most_frequent’ and ‘constant’.

# %% [markdown]
# Let's start by importing the `SimpleImputer` into our notebook

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values = np.nan,  
                        strategy ='median')

# %% [markdown]
# What we need to do are two essential steps:
#
# 1. fit the data (compute the mean / median / most freq)
# 2. transform the data (place the computed values in the NaN cells)

# %%
imputer = imputer.fit(df_cars.iloc[:,1:8])

# %%
df_cars.iloc[:,1:8] = imputer.transform(df_cars.iloc[:,1:8])

# %%
df_cars.head()
# Out:
#                          Car      MPG Cylinders Displacement Horsepower  \
# 1  Chevrolet Chevelle Malibu  23.1342         8          307        130
# 2          Buick Skylark 320       15         8          350       92.5
# 3         Plymouth Satellite  23.1342         8          318        150
# 4              AMC Rebel SST       16         8          151        150
# 5                Ford Torino       17         8          302        140
#
#   Weight Acceleration Model Origin
# 1   3504           12    70     US
# 2   3693         11.5    70     US
# 3   3436           11    70     US
# 4   2815           12    70     US
# 5   3449         10.5    70     US

# %% [markdown]
# ### **Data Cleaning Exercise - SF Building permit**
#
#
# The [Building permits dataset](https://www.kaggle.com/aparnashastry/building-permit-applications-data#Building_Permits.csv) pertains to all types of structural permits from Jan 1, 2013 - Feb 25th 2018 in San Francisco. Data includes details on application/permit numbers, job addresses, supervisorial districts, and the current status of the applications.
#
# Download the dataset from the link provided and store it in your own data or working folder. Import the dataset in the next cell, and work your way through the steps in the subsequent cells.

# %% [markdown]
# 1. Import the dataset and observe the first few rows

# %%
building_permits_df = pd.read_csv(get_path("Building_Permits.csv",env_name='local'),low_memory=False)
building_permits_df.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# 1       Geary            St  ...                         3.0
# 2     Pacific            Av  ...                         1.0
# 3     Pacific            Av  ...                         5.0
# 4      Market            St  ...                         3.0
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          constr type 3                        NaN
# 1                          constr type 3                        NaN
# 2                          constr type 1                        1.0
# 3                         wood frame (5)                        5.0
# 4                          constr type 3                        NaN
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          constr type 1         NaN                 3.0
# 3                         wood frame (5)         NaN                 3.0
# 4                                    NaN         NaN                 6.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          Tenderloin  94102.0
# 1                          Tenderloin  94102.0
# 2                        Russian Hill  94109.0
# 3                            Nob Hill  94109.0
# 4                          Tenderloin  94102.0
#
#                                     Location      Record ID
# 0  (37.785719256680785, -122.40852313194863)  1380611233945
# 1   (37.78733980600732, -122.41063199757738)  1420164406718
# 2    (37.7946573324287, -122.42232562979227)  1424856504716
# 3   (37.79595867909168, -122.41557405519474)  1443574295566
# 4   (37.78315261897309, -122.40950883997789)   144548169992
#
# [5 rows x 43 columns]

# %% [markdown]
# 2. Find out what percent of the building permits dataset is missing.

# %% [markdown]
# 3. Write a code to check the values of the `Street Number Suffix` and `Zipcode` from the building permits datasets. Both of these contain missing values. Which, if either, of these are missing because they don't exist? Which, if either, are missing because they weren't recorded?

# %% [markdown]
# 4. See if you can drop the missing values from the building permits dataset and still keep some data, or drop the columns with missing values and see if you have columns still.

# %%
building_permits_df.dropna(axis=1)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# 1                04/19/2016  0306   007            440       Geary
# 2                05/27/2016  0595   203           1647     Pacific
# 3                11/07/2016  0156   011           1230     Pacific
# 4                11/28/2016  0342   001            950      Market
# ...                     ...   ...   ...            ...         ...
# 198895           12/05/2017  0113  017A           1228  Montgomery
# 198896           12/05/2017  0271   014            580        Bush
# 198897           12/06/2017  4318   019           1568     Indiana
# 198898           12/06/2017  0298   029            795      Sutter
# 198899           12/07/2017  0160   006            838     Pacific
#
#        Current Status Current Status Date  Filed Date      Record ID
# 0             expired          12/21/2017  05/06/2015  1380611233945
# 1              issued          08/03/2017  04/19/2016  1420164406718
# 2           withdrawn          09/26/2017  05/27/2016  1424856504716
# 3            complete          07/24/2017  11/07/2016  1443574295566
# 4              issued          12/01/2017  11/28/2016   144548169992
# ...               ...                 ...         ...            ...
# 198895         issued          12/05/2017  12/05/2017  1489337276729
# 198896         issued          12/06/2017  12/05/2017  1489462354993
# 198897         issued          12/06/2017  12/06/2017  1489539379952
# 198898         issued          12/06/2017  12/06/2017  1489608233656
# 198899         issued          12/07/2017  12/07/2017  1489796283803
#
# [198900 rows x 12 columns]

# %% [markdown]
# 5. Try replacing all the `NaN`'s in the building permits data with the one that comes directly after it and then replacing any remaining `NaN`'s with 0. **HINT:** Google `fillna(method = 'bfill')`

# %%
new_df = building_permits_df.fillna(method='bfill').fillna(0)

# %% [markdown]
# 6. Create a new dataset at the end with all missing values handled and store as a CSV file.

# %%
new_df.to_csv('new dataframe.csv')

# %% [markdown]
# ### **Data Cleaning Exercise 2: Missing value handling on the Pima**
#
# [Pima Indians Diabetes Dataset](https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv) involves predicting the onset of diabetes within 5 years in Pima Indians given medical details.
#
# There are 768 observations with 8 input variables and 1 output variable. The variable names are as follows:
#
# 0. Number of times pregnant.
# 1. Plasma glucose concentration a 2 hours in an oral glucose tolerance test.
# 2. Diastolic blood pressure (mm Hg).
# 3. Triceps skinfold thickness (mm).
# 4. 2-Hour serum insulin (mu U/ml).
# 5. Body mass index (weight in kg/(height in m)^2).
# 6. Diabetes pedigree function.
# 7. Age (years).
# 8. Class variable (0 or 1).
#
# This is a medical dataset, so an important thing we will do with this dataset is that we will see if the statistical summaries can reveal something about the missing values.

# %% [markdown]
# 1. Import the dataset in the next cell, and work your way through the steps in the subsequent cells.

# %%
pima_df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv',header=None)
pima_df.columns = ['Number of times pregnant','Plasma glucose concentration','Diastolic blood pressure','Triceps skinfold thickness','2-Hour serum insulin','BMI',' Diabetes pedigree function','Age','Class variable']
pima_df.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                           148
# 1                         1                            85
# 2                         8                           183
# 3                         1                            89
# 4                         0                           137
#
#    Diastolic blood pressure  Triceps skinfold thickness  2-Hour serum insulin  \
# 0                        72                          35                     0
# 1                        66                          29                     0
# 2                        64                           0                     0
# 3                        66                          23                    94
# 4                        40                          35                   168
#
#     BMI   Diabetes pedigree function  Age  Class variable
# 0  33.6                        0.627   50               1
# 1  26.6                        0.351   31               0
# 2  23.3                        0.672   32               1
# 3  28.1                        0.167   21               0
# 4  43.1                        2.288   33               1

# %% [markdown]
# 2. Use the describe method used for pandas data frames to obtain a statistucal summary of the dataset.

# %%
pima_df.describe()
# Out:
#        Number of times pregnant  Plasma glucose concentration  \
# count                768.000000                    768.000000
# mean                   3.845052                    120.894531
# std                    3.369578                     31.972618
# min                    0.000000                      0.000000
# 25%                    1.000000                     99.000000
# 50%                    3.000000                    117.000000
# 75%                    6.000000                    140.250000
# max                   17.000000                    199.000000
#
#        Diastolic blood pressure  Triceps skinfold thickness  \
# count                768.000000                  768.000000
# mean                  69.105469                   20.536458
# std                   19.355807                   15.952218
# min                    0.000000                    0.000000
# 25%                   62.000000                    0.000000
# 50%                   72.000000                   23.000000
# 75%                   80.000000                   32.000000
# max                  122.000000                   99.000000
#
#        2-Hour serum insulin         BMI   Diabetes pedigree function  \
# count            768.000000  768.000000                   768.000000
# mean              79.799479   31.992578                     0.471876
# std              115.244002    7.884160                     0.331329
# min                0.000000    0.000000                     0.078000
# 25%                0.000000   27.300000                     0.243750
# 50%               30.500000   32.000000                     0.372500
# 75%              127.250000   36.600000                     0.626250
# max              846.000000   67.100000                     2.420000
#
#               Age  Class variable
# count  768.000000      768.000000
# mean    33.240885        0.348958
# std     11.760232        0.476951
# min     21.000000        0.000000
# 25%     24.000000        0.000000
# 50%     29.000000        0.000000
# 75%     41.000000        1.000000
# max     81.000000        1.000000

# %% [markdown]
# 3. There are columns that have a minimum value of zero (0). On some columns, a value of zero does not make sense and indicates an invalid or missing value. For example, the `BMI` for a person cannot be 0. See if there are other columns/attributes whose value of 0 does not make sense. An understanding of the medical columns may be needed.

# %%
# Out:
#        Number of times pregnant  Plasma glucose concentration  \
# count                768.000000                    763.000000
# mean                   3.845052                    121.686763
# std                    3.369578                     30.535641
# min                    0.000000                     44.000000
# 25%                    1.000000                     99.000000
# 50%                    3.000000                    117.000000
# 75%                    6.000000                    141.000000
# max                   17.000000                    199.000000
#
#        Diastolic blood pressure  Triceps skinfold thickness  \
# count                733.000000                  541.000000
# mean                  72.405184                   29.153420
# std                   12.382158                   10.476982
# min                   24.000000                    7.000000
# 25%                   64.000000                   22.000000
# 50%                   72.000000                   29.000000
# 75%                   80.000000                   36.000000
# max                  122.000000                   99.000000
#
#        2-Hour serum insulin         BMI   Diabetes pedigree function  \
# count            394.000000  757.000000                   768.000000
# mean             155.548223   32.457464                     0.471876
# std              118.775855    6.924988                     0.331329
# min               14.000000   18.200000                     0.078000
# 25%               76.250000   27.500000                     0.243750
# 50%              125.000000   32.300000                     0.372500
# 75%              190.000000   36.600000                     0.626250
# max              846.000000   67.100000                     2.420000
#
#               Age  Class variable
# count  768.000000      768.000000
# mean    33.240885        0.348958
# std     11.760232        0.476951
# min     21.000000        0.000000
# 25%     24.000000        0.000000
# 50%     29.000000        0.000000
# 75%     41.000000        1.000000
# max     81.000000        1.000000

# %% [markdown]
# 4. Now you can proceed to check the missing values and remove/impute as in exercise 1. Create a new dataset at the ending with all missing values handled and store as a CSV file.

# %% [markdown]
# ##**References**

# %% [markdown]
# **Pictures**
#
#
# 1. https://devbunch.com/blog/6-data-cleaning-steps-to-boost-busin/
#
#
# **Notebook Resources**
# 1. [Hadley Wickham - Tidy Data](http://vita.had.co.nz/papers/tidy-data.pdf)
# 2. [Data Cleaning](https://www.kaggle.com/rtatman/data-cleaning-challenge-handling-missing-values)
# 3. [DSangeetha- Nobel Prize Visualization](https://www.kaggle.com/devisangeetha/nobel-prizes-from-1901)
# 4. [Simple Imputer](https://www.youtube.com/watch?v=GFnwvZVCMro)
# 5. [Geeks for Geeks - Simple Imputer](https://www.geeksforgeeks.org/ml-handle-missing-data-with-simple-imputer/)
